# %% [markdown]
# # Model Evaluation
#
# This notebook evaluates the saved final churn model and regenerates report figures.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from evaluate_model import evaluate

metrics = evaluate(threshold=0.5)
metrics
# Out:
# {'roc_auc': 0.8407343752426607,
#  'precision': 0.6445182724252492,
#  'recall': 0.5187165775401069,
#  'f1': 0.5748148148148148,
#  'true_positives': 194.0,
#  'false_positives': 107.0,
#  'false_negatives': 180.0,
#  'true_negatives': 926.0}

# %% [markdown]
# The generated outputs are saved under `reports/`:
#
# - `reports/churn_report.md`
# - `reports/figures/roc_curve.png`
# - `reports/figures/precision_recall_curve.png`
# - `reports/figures/confusion_matrix.png`
# - `reports/figures/feature_importance.png`
